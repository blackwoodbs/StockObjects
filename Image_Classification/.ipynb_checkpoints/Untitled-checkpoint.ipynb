# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
simple_model = keras.models.load_model('models/simple_model/')

# %%
import pandas as pd

# %%
df = pd.read_json('candles-2022-02-22T011818.coco.json', lines=True)
df.annotations
# Out:
# 0    [{'id': 1, 'image_id': 1, 'category_id': 1, 's...
# Name: annotations, dtype: object

# %%
import json

# %%
with open('candles-2022-02-22T011818.coco.json') as f:
    jason = json.load(f)

# %%
jason
# Out:
# {'info': {'contributor': '',
#   'date_created': '',
#   'description': '',
#   'url': '',
#   'version': '',
#   'year': ''},
#  'licenses': [{'name': '', 'id': 0, 'url': ''}],
#  'annotations': [{'id': 1,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[61.53192270058673,
#      623.274094911937,
#      86.41352739725994,
#      623.274094911937,
#      86.41352739725994,
#      469.8856409001953,
#      61.53192270058673,
#      469.8856409001953,
#      61.53192270058673,
#      623.274094911937]],
#    'area': 3816.550877753995,
#    'bbox': [61.53192270058673,
#     469.8856409001953,
#     24.88160469667321,
#     153.3884540117417],
#    'iscrowd': 0},
#   {'id': 2,
#    'image_id': 1,
#    'category_id': 2,
#    'segmentation': [[799.132950097847,
#      791.7877935420739,
#      821.5682485322893,
#      791.7877935420739,
#      821.5682485322893,
#      571.7862035225045,
#      799.132950097847,
#      571.7862035225045,
#      799.132950097847,
# ...
